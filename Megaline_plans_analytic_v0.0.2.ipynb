# %% [markdown]
# **Hello Kamil!**
#
# My name is Alex, and I will review your project on Statistical Data Analysis! I have added all my comments to new cells with different coloring. If the project contains one or more red comments, it will be rejected for fixing. Please, do not move or delete my comments - it helps us move faster.
#
# <div class="alert alert-success">
# <b>Reviewer's comment v.1</b>
#
# I am using green color for my comment if everything is done successfully.
# </div>
# <div class="alert alert-warning">
#
# <b>Reviewer's comment v.1</b>
#
# I will use yellow color for my comment if I can give you a recommendation or think that something can be improved. This is an optional recommendation, but it will be perfect if you work with them.
# </div>
#
# <div class="alert alert-danger">
# <b>Reviewer's comment v.1</b>
#
# I am using red color for my comment if the block requires some extra work or corrections. The project couldn’t be accepted with red comments.
# </div>
#
# To make a dialog, let’s use this style for your remarks:
# <div class="alert alert-info">
# <b>Student's comment</b>
#
# Just like this. To make a similar block - double click on the block , copy and edit it in places you are changing.
# </div>
#
# Now, let’s go to data analysis!
#
# ---
#
# <div class="alert alert-danger">
# <b>General feedback v.1</b>
#
# Kamil, thank you for sending your project. You have done a perfect job on it! I like the way you have done prepared the data and testing hypotheses in your project. It is good that you have used functions and automatized the code! However, few things need to be corrected in your project. They are mostly minor issues that are easy to fix. You will find them as red comments. As a recommendation: feel free to comment on the main analysis steps and obtained data, suggest hypotheses for some problems with data, or get some results.
#
# <br>
# Keep up the good work, and come back soon!
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment</b>
#
# Hello Alex! It is very pleasant to work with the reviewer. Very cool advice and to be honest, I somehow took a different look at the analytics process. So far, the truth is only possible, at the beginning to describe your thoughts in another language, and then translate into English. Thank you very much for the information. I hope I haven't forgotten anything. If I have forgotten, I will correct it. I think I understand your main idea about writing conclusions. I do not take into account the conclusions on this project work. But now I understand more how to write conclusions better. While you are checking, I will switch to an integration project to have time to turn in everything.
# </div>

# %% [markdown]
# # Megaline Plans Analytics

# %% [markdown]
# # Table of contents

# %% [markdown]
# 1. [Project Description](#ProjectDescription)
# 2. [Step 1: Open data and general information](#OpenData&GeneralInfo)
# 3.   [* Step 1: Conclusion](#GeneranlInfoConclusion)
# 4. [Step 2: Prepare the Data](#PrepareData)
# 5. [* To Do List](#Step2ToDoList)
# 6. [**Prepare Call Data](#PrepareCallData)
# 7. [**Prepare Internet Data](#PrepareInternetData)
# 8. [**Prepare Message Data](#PrepareMessageData)
# 9. [**Prepare User Data](#PrepareUserData)
# 10. [**Calculation User's Overage](#CalculationOverage)
# 11. [**Calculation Revenue](#CalculationRevenue)
# 12.  [* Step 2: Conclusion](#Step2Conclusion)
# 13. [Step 3: Analyze the data](#AnalyzeData)
# 14.  [* Step 3: Conclusion](#Step3Conclusion)
# 15. [Step 4: Test the Hypotheses](#Step4Hypotheses)
# 16. [**Null Hypotheses 1](#NullHypotheses1)
# 17. [**Null Hypotheses 1 Conclusion:](#NullHypotheses1Conclusion)
# 18. [**Null Hypotheses 2](#NullHypotheses2)
# 19. [**NUll Hypotheses 2 Conclusion:](#NullHypotheses2Conclusion)
# 20.  [* Step 4: Conclusion](#Step4Conclusion)
# 21. [Step 5: Write an overall conclusion](#OverallConclusion)

# %% [markdown]
# ### Project Description. <a name="ProjectDescription"></a>

# %% [markdown]
# |  Name  |  Description  |
# | :----: |  :---- |
# |  **Initial conditions**  | You work as an analyst for the telecom operator Megaline. The company offers its clients two prepaid plans, Surf and Ultimate. .  |
# |  **Main question of project**  |  Which of the plans brings in more revenue in order to adjust the advertising budget |
# | **Project Description**  | [Link to Project Description](https://practicum.yandex.com/learn/data-scientist/courses/8379ed9f-b704-4f1c-9dad-6907efb24928/sprints/4249/topics/01e1acb8-80e6-4d68-9022-a08914dba234/lessons/e8470419-0985-4deb-ba06-b0b350198953/)    |
# | **Datasets**             | [/datasets/megaline_calls.csv](https://code.s3.yandex.net/datasets/megaline_calls.csv)  |
# |                          | [/datasets/megaline_internet.csv](https://code.s3.yandex.net/datasets/megaline_internet.csv) |
# |                          | [/datasets/megaline_messages.csv](https://code.s3.yandex.net/datasets/megaline_messages.csv) |
# |                          | [/datasets/megaline_plans.csv](https://code.s3.yandex.net/datasets/megaline_plans.csv) |
# |                          | [/datasets/megaline_users.csv](https://code.s3.yandex.net/datasets/megaline_users.csv) |

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Good start! We have a brief project description and a table of contents. It is good to share the references to the project description; however, we could also copy the project and data description here. It will be more useful for the reader.
# </div>

# %% [markdown]
# ### Step 1. Open the data file and study the general information. <a name="OpenData&GeneralInfo"></a>

# %%
# import all packages
import pandas as pd
import numpy as np
import random
from scipy import stats as st

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Great that all imports are collected in the first cell!
# </div>

# %%
# connect all datasets:
df_calls = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_calls.csv')
df_internet = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_internet.csv')
df_messages = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_messages.csv')
df_plans = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_plans.csv')
df_users = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_users.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Good! All data were opened correctly.
# </div>

# %%
# function to determine if columns in file have null values:
def get_percent_of_na(df, num):
    count = 0; # first reset counter.
    df = df.copy() # copy dataframe in new structure.
    amount = (df.isna().sum() / df.shape[0])
    
    for column, percent in zip(amount.index, amount.values):
        num_of_nulls = df[column].isna().sum()
        if num_of_nulls == 0:
            continue
        else:
            count += 1
        print('Column {} has {:.{}%} percent of Nulls, and {} of nulls'.format(column, percent, num, num_of_nulls))
        
    if count != 0:
        print('\033[1m' + 'There are {} columns with NA.'.format(count) + '\033[0m')
    else: 
        print()
        print('\033[1m' + 'There are no columns with NA.' + '\033[0m')

# %%
# function to display helpfull information about each file.
def get_info(df):
    print('Head:')
    display(df.head())
    print('-'*110)
    
    print('Info:')
    display(df.info())
    print('-'*110)
    
    print('Describe:')
    display(df.describe())
    display(df.describe(include='object'))
    print('-'*110)
    
    print('Columns with nulls:')
    get_percent_of_na(df_calls, 2)
    print('-'*110)
    
    print('Shape:')
    print(df.shape)
    print('-'*110)
    
    print('Duplicated:')
    print('\033[1m' + 'We have {} duplicated rows. \n'.format(df.duplicated().sum()) + '\033[0m')
    print('/'*110)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# It is brilliant that you have used functions and automatization to get the main information regarding the data! I like that you have used the `.copy()` method during work with dataframes.
# </div>

# %%
# let's use get_info function for check information for all datasets:
get_info(df_calls)
get_info(df_internet)
get_info(df_messages)
get_info(df_plans)
get_info(df_users)
# Out:
# Head:
#          id  user_id   call_date  duration
# 0   1000_93     1000  2018-12-27      8.52
# 1  1000_145     1000  2018-12-27     13.66
# 2  1000_247     1000  2018-12-27     14.48
# 3  1000_309     1000  2018-12-28      5.76
# 4  1000_380     1000  2018-12-30      4.22
# --------------------------------------------------------------------------------------------------------------
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137735 entries, 0 to 137734
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         137735 non-null  object
#  1   user_id    137735 non-null  int64
#  2   call_date  137735 non-null  object
#  3   duration   137735 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB
# None
# --------------------------------------------------------------------------------------------------------------
# Describe:
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Well done! Now we have the main information about the data!
# </div>

# %%
df_users.query('user_id == "1499"')
# Out:
#      user_id first_name last_name  age                               city  \
# 499     1499      Shena   Dickson   37  Orlando-Kissimmee-Sanford, FL MSA
#
#        reg_date  plan churn_date
# 499  2018-05-06  surf        NaN

# %% [markdown]
# #### Step1: Conclusion <a name="GeneranlInfoConclusion"></a>

# %% [markdown]
# Based on the above information:
# > * All 5 datasets, with the exception of the plans dataset, have an Id and a User Id columns.
# * Subsequently, we can combine these different sets of data about used messages, minutes, Internet traffic (used Mbytes) and user data into a common data set to personalize all this data. For their subsequent analysis.
# * The average call time is 6 minutes, the maximum call lasted 37 minutes.
# * The average amount of Internet traffic is 366 megabytes. The maximum volume is 1700 megabytes (Note: in accordance with the tariff plan policy, we round up the amount of used megabytes).
# * The maximum age of users is 75, the minimum is 18. The average age is 45-46 years.
# * Interesting fact. The user under ID 1499, according to the presented data, has the maximum length of calls and spent megabytes. This woman, her age is 37 years old. And she uses the Surf tariff plan.
# * We can say that there are no missing values in the datasets. Very clean data.

# %% [markdown]
# * [X] Provide more information in the conclusion.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Correct, the data look correct. However, I would suggest that we could improve the conclusions on this step. I believe that they should be more detailed. For example, we have used the `.describe()` method, but we have not described the results.
#
# Could you please study each dataframe separately and suggest some conclusions for each data frame.
#
# Let's do not forget that we make the report for business. In our case, for someone from Megaline company, most probably for a product manager. Likely, a product manager does not know python, and we should describe all our steps and make detailed understandable conclusions.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment: </b>
#    To be honest, I don't seem to quite understand what product managers know. What is their usual background and up to what point they need to explain. Do you have any links to articles about the "typical profile" of the average customer (client) - that is, the product of a manager or other role. Or perhaps, based on your experience of communicating with such people, you can ask the relevant questions that such "clients" in this chain usually voice?
# </div>

# %% [markdown]
# ### Step 2. Prepare the data <a name="PrepareData"></a>

# %% [markdown]
# #### To-Do List: <a name="Step2ToDoList"></a>

# %% [markdown]
# > - [X] Convert the data to the necessary types
# - [X] Find and eliminate errors in the data
# - [X] Explain what errors you found and how you removed them.

# %% [markdown]
# **For each user, find:**
# > - [x] The number of calls made and minutes used per month
# - [x] The number of text messages sent per month
# - [x] The volume of data per month
# - [x] The monthly revenue from each user (subtract the free package limit from the total number of calls, text messages, and data; multiply the result by the calling plan value; add the monthly charge depending on the calling plan)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Good strategy!
# </div>

# %%
#get_id = np.vectorize(lambda x: re.sub('.*_', '' , x)) - under check.

# %%
# change data types to datetime and split into day/month/year columns:
def get_info_date(df):
    columns = df.columns.tolist()
    idx = [columns.index(x) for x in columns if 'date' in x][0]
    
    df[columns[idx]] = pd.to_datetime(df[columns[idx]])
    df['day'] = df[columns[idx]].dt.day_name()
    df['month'] = df[columns[idx]].dt.month_name()
    df['year'] = df[columns[idx]].dt.year
    return df

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# <b>Reviewer's comment v.1</b>
#
# Well done! However, probably making columns with day and year seems like extra actions. If we do not use them in data analysis, we could miss this step.
# </div>

# %% [markdown]
# #### Prepare Call Data <a name="PrepareCallData"></a>

# %%
# let't check df_calls columns: 
df_calls.columns
# Out:
# Index(['id', 'user_id', 'call_date', 'duration'], dtype='object')

# %%
df_calls['call_date'] = pd.to_datetime(df_calls['call_date'])
df_calls = get_info_date(df_calls)
df_calls['call_type'] = np.where(df_calls['duration'] == 0, 'Missed call', 'Connected call')
df_calls.head()
# Out:
#          id  user_id  call_date  duration       day     month  year  \
# 0   1000_93     1000 2018-12-27      8.52  Thursday  December  2018
# 1  1000_145     1000 2018-12-27     13.66  Thursday  December  2018
# 2  1000_247     1000 2018-12-27     14.48  Thursday  December  2018
# 3  1000_309     1000 2018-12-28      5.76    Friday  December  2018
# 4  1000_380     1000 2018-12-30      4.22    Sunday  December  2018
#
#         call_type
# 0  Connected call
# 1  Connected call
# 2  Connected call
# 3  Connected call
# 4  Connected call

# %%
df_calls.query('duration == "Missed call"')
# Out:
# Empty DataFrame
# Columns: [id, user_id, call_date, duration, day, month, year, call_type]
# Index: []

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment: </b>
# Additional check to make sure there are no calls with zero duration - "Missed call". If such calls existed, then it would be necessary to analyze them. Why they could have arisen and how they affect the overall statistics. In this case, we can say that it was overwork.
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Excellent! We have detected the zero duration for some calls and categorized the calls into two types. However, it is not clear why we did that? Could you please describe the calls with zero durations and what we will do with them?
# </div>

# %% [markdown]
# > * **Note**: Megaline rounds seconds up to minutes, and megabytes to gigabytes. For calls, each individual call is rounded up: even if the call lasted just one second, it will be counted as one minute

# %% [markdown]
# In accordance with this rule, we will round the duration of the conversation to whole values.

# %%
df_calls['duration'] = df_calls['duration'].apply(np.ceil)
df_calls.head()
# Out:
#          id  user_id  call_date  duration       day     month  year  \
# 0   1000_93     1000 2018-12-27       9.0  Thursday  December  2018
# 1  1000_145     1000 2018-12-27      14.0  Thursday  December  2018
# 2  1000_247     1000 2018-12-27      15.0  Thursday  December  2018
# 3  1000_309     1000 2018-12-28       6.0    Friday  December  2018
# 4  1000_380     1000 2018-12-30       5.0    Sunday  December  2018
#
#         call_type
# 0  Connected call
# 1  Connected call
# 2  Connected call
# 3  Connected call
# 4  Connected call

# %% [markdown]
# * [X] Rounds calls from seconds up to minutes.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# What is about Megaline's rules for rounding calls? Yes, rounding was done in the following steps, but I would suggest that we should rounding-up each call here.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment:</b> Good point, I forgot about it. Thanks.
# </div>

# %% [markdown]
# #### Prepare Internet Data <a name="PrepareInternetData"></a>

# %%
# let's prepare additional columns with day/month/year for dataframe with internet traffic.
df_internet = get_info_date(df_internet)
# check results:
df_internet.head(20)
# Out:
#           id  user_id session_date  mb_used        day      month  year
# 0    1000_13     1000   2018-12-29    89.86   Saturday   December  2018
# 1   1000_204     1000   2018-12-31     0.00     Monday   December  2018
# 2   1000_379     1000   2018-12-28   660.40     Friday   December  2018
# 3   1000_413     1000   2018-12-26   270.99  Wednesday   December  2018
# 4   1000_442     1000   2018-12-27   880.22   Thursday   December  2018
# 5     1001_0     1001   2018-08-24   284.68     Friday     August  2018
# 6     1001_3     1001   2018-12-09   656.04     Sunday   December  2018
# 7     1001_4     1001   2018-11-04    16.97     Sunday   November  2018
# 8    1001_10     1001   2018-11-27   135.18    Tuesday   November  2018
# 9    1001_15     1001   2018-12-13   761.92   Thursday   December  2018
# 10   1001_16     1001   2018-10-28   501.53     Sunday    October  2018
# 11   1001_17     1001   2018-09-05   727.29  Wednesday  September  2018
# ...

# %%
# df_internet.loc[df_internet['mb_used'] == 0.00].value_counts - will be fixed in new version. I hope. Seems like - no. I need to pass integration project. Хоспади, спасибо Практикуму за 4-ые выходные без выходных чтобы успеть в срок. Но зато я хоть теперь по утрам учится начал, до работы. Нокия. Краков. 2 года дома не был.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Reviewer's comment v.1</b>
#
# In this data frame, we also have zero values within the `mb_used` column. Could you please describe that and suggest what we should do in this case?
# </div>

# %% [markdown]
# #### Prepare Message Data <a name="PrepareMessageData"></a>

# %%
# add additional columns for Messages Dataframe.
df_messages = get_info_date(df_messages)
df_messages.head()
# Out:
#          id  user_id message_date        day     month  year
# 0  1000_125     1000   2018-12-27   Thursday  December  2018
# 1  1000_160     1000   2018-12-31     Monday  December  2018
# 2  1000_223     1000   2018-12-31     Monday  December  2018
# 3  1000_251     1000   2018-12-27   Thursday  December  2018
# 4  1000_255     1000   2018-12-26  Wednesday  December  2018

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Correct!
# </div>

# %% [markdown]
# #### Prepare User Data <a name="PrepareUserData"></a>

# %%
# first check data view from Users dataframe.
df_users.head()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#      reg_date      plan churn_date
# 0  2018-12-24  ultimate        NaN
# 1  2018-08-13      surf        NaN
# 2  2018-10-21      surf        NaN
# 3  2018-01-28      surf        NaN
# 4  2018-05-23      surf        NaN

# %%
# add new columns: registration date and terminate date:
df_users['reg_date'] = pd.to_datetime(df_users['reg_date'])
df_users['churn_date'] = pd.to_datetime(df_users['churn_date'])
df_users.head()
# Out:
#    user_id first_name  last_name  age                                   city  \
# 0     1000   Anamaria      Bauer   45  Atlanta-Sandy Springs-Roswell, GA MSA
# 1     1001     Mickey  Wilkerson   28        Seattle-Tacoma-Bellevue, WA MSA
# 2     1002     Carlee    Hoffman   36   Las Vegas-Henderson-Paradise, NV MSA
# 3     1003   Reynaldo    Jenkins   52                          Tulsa, OK MSA
# 4     1004    Leonila   Thompson   40        Seattle-Tacoma-Bellevue, WA MSA
#
#     reg_date      plan churn_date
# 0 2018-12-24  ultimate        NaT
# 1 2018-08-13      surf        NaT
# 2 2018-10-21      surf        NaT
# 3 2018-01-28      surf        NaT
# 4 2018-05-23      surf        NaT

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Well done!
# </div>

# %%
print(df_users['user_id'].nunique())
print(df_calls['user_id'].nunique())
print(df_internet['user_id'].nunique())
print(df_messages['user_id'].nunique())
# Out:
# 500
# 481
# 489
# 402

# %%
# calls per user per month
calls_made = df_calls.groupby(['user_id','month']).agg({'id':'count'}).rename(columns={'id':'Calls Made'})

# minutes per user per month
min_spent = df_calls.groupby(['user_id','month']).agg({'duration':'sum'}).rename(columns={'duration':'Minutes Spent'})

# traffic per user per month
mb_used = df_internet.groupby(['user_id','month']).agg({'mb_used':'sum'}).rename(columns={'mb_used':'Mb Used'})

# messages per user per month
messages_sent = df_messages.groupby(['user_id','month']).agg({'id':'count'}).rename(columns={'id':'Messages Sent'})

# %%
# plan for each user
plan = df_users[['user_id','plan']]

# combined into one table
df_usage = pd.concat([calls_made, min_spent, mb_used, messages_sent], axis=1).reset_index().merge(plan,on='user_id')
# main notice. Amount of internet traffic still in Mb. 
df_usage.head(15)
# Out:
#     user_id      month  Calls Made  Minutes Spent   Mb Used  Messages Sent  \
# 0      1000   December        16.0          124.0   1901.47           11.0
# 1      1001     August        27.0          182.0   6919.15           30.0
# 2      1001   December        56.0          412.0  19369.18           44.0
# 3      1001   November        64.0          426.0  18504.30           36.0
# 4      1001    October        65.0          393.0  22330.49           53.0
# 5      1001  September        49.0          315.0  13314.82           44.0
# 6      1002   December        47.0          384.0  14396.24           41.0
# 7      1002   November        55.0          386.0  19345.08           32.0
# 8      1002    October        11.0           59.0   6552.01           15.0
# 9      1003   December       149.0         1104.0  27044.14           50.0
# 10     1004     August        49.0          354.0  27981.74           25.0
# ...

# %%
# Saving new obtained dataframe as a csv file
df_usage.to_csv('usage_data.csv', index=False)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Correct! The final pivot table has been made.
# </div>

# %% [markdown]
# #### Calculation User's Overage <a name="CalculationOverage"></a>

# %%
# import all packages once again for not scroll to up. 
import pandas as pd
import numpy as np
import random

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Reviewer's comment v.1</b>
#
# It is not necessary to import modules a second time
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment: </b> The main reason why I import these libraries again is so that I can start right from this point of the project. It is inconvenient to go upstairs and go through the whole project. It is possible to somehow automatically initialize the import of these libraries, but I don't know how to do that yet. Perhaps in combination Jupiter Notebook + Visual Studio Code you can somehow solve this.
# </div>

# %%
# Re-upload once again, if stopped in this point.
df_usage = pd.read_csv('usage_data.csv')
df_plans = pd.read_csv('https://code.s3.yandex.net/datasets/megaline_plans.csv')

# %%
# let's check again missing values for new created table.
df_usage.isnull().sum()
# Out:
# user_id            0
# month              0
# Calls Made        35
# Minutes Spent     35
# Mb Used           16
# Messages Sent    487
# plan               0
# dtype: int64

# %%
# prepare function to fill missing values. 
def fill_na(df):
    if df.isna().sum().sum() != 0: 
        df.fillna(0, inplace=True)
    return df

# %%
# fill missing values in new DataFrame.
fill_na(df_usage)
# Out:
#       user_id      month  Calls Made  Minutes Spent   Mb Used  Messages Sent  \
# 0        1000   December        16.0          124.0   1901.47           11.0
# 1        1001     August        27.0          182.0   6919.15           30.0
# 2        1001   December        56.0          412.0  19369.18           44.0
# 3        1001   November        64.0          426.0  18504.30           36.0
# 4        1001    October        65.0          393.0  22330.49           53.0
# ...       ...        ...         ...            ...       ...            ...
# 2288     1498  September        45.0          363.0  22827.28            0.0
# 2289     1499   December        65.0          496.0  22059.21            0.0
# 2290     1499   November        45.0          308.0  16813.83            0.0
# 2291     1499    October        53.0          385.0  19492.43            0.0
# 2292     1499  September        41.0          346.0  12984.76            0.0
#
#           plan
# 0     ultimate
# ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Student's comment: </b>
# I think that in this case, I cannot describe the nature of the missing values, since I do not know how this data was collected. Please give me a hint. I seem to be missing something. The information should most likely be somewhere on the surface. I believe that in this case, it is better to fill the missing values with zeros, since in the future these lines will not affect the overrun of used minutes, megabytes and messages. It seems to me that if I use the average when filling in the missing values, then this can "correct" the indicators of the used resources for the better.
# </div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# It is absolutely correct! However, could you please describe the nature of these missings and why we fill them by 0?
# </div>

# %%
# let's see again to all plans from Megaline.
df_plans.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute plan_name
# 0               20          10             0.03            0.03      surf
# 1               70           7             0.01            0.01  ultimate

# %%
# check again df_usage columns:
df_usage.columns
# Out:
# Index(['user_id', 'month', 'Calls Made', 'Minutes Spent', 'Mb Used',
#        'Messages Sent', 'plan'],
#       dtype='object')

# %%
# function to calculate if a user is over plan usage for calls, minutes and internet traffic.
def calculate_overage(df, df_plan):
    
    # define new overage DataFrame for minutes, messages and traffic:
    over_minutes  = []
    over_messages = []
    over_traffic  = []
    
    # ultimate plan allowances: 
    ultimate_messages = 1000 # 1000 SMS
    ultimate_traffic  = 30720 # 30Gbytes traffic included.
    ultimate_minutes  = 3000 # 3000 minutes.
    
    # surf plan allowances:
    surf_messages = 50 # 50 SMS
    surf_traffic  = 15360 # 15Gbytes traffic included.
    surf_minutes  = 500
    
    for min_spent, mb_used, messages_sent, plan in zip(df['Minutes Spent'], df['Mb Used'], df['Messages Sent'], df['plan']):
        if plan == 'ultimate': # first branch - check Ultimate plan
            if min_spent <= ultimate_minutes:
                over_minutes.append(0)
            else:
                over_minutes.append(min_spent-ultimate_minutes)
                
            if mb_used <= ultimate_traffic:
                over_traffic.append(0)
            else:
                over_traffic.append(mb_used-ultimate_traffic)
                
            if messages_sent <= ultimate_messages:
                over_messages.append(0)
            else:
                over_messages.append(messages_sent-ultimate_messages)
                
        else: # another branch - check Surf plan
            if min_spent <= surf_minutes:
                over_minutes.append(0)
            else:
                over_minutes.append(min_spent-surf_minutes)
                
            if mb_used <= surf_traffic:
                over_traffic.append(0)
            else:
                over_traffic.append(mb_used-surf_traffic)
                
            if messages_sent <= surf_messages:
                over_messages.append(0)
            else:
                over_messages.append(messages_sent-surf_messages)
    # np.ceil.
    return np.ceil(over_minutes), np.ceil(over_traffic), np.ceil(over_messages)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Brilliant work! It is nice to see here the `zip` function! As some recommendation: it is better to use variables for a calling plan' limits. It will make your code more universal if some information about calling plans changed.
# </div>

# %% [markdown]
# An additional step is rounding up the used minutes and Internet traffic:

# %%
df_usage.head()
# Out:
#    user_id     month  Calls Made  Minutes Spent   Mb Used  Messages Sent  \
# 0     1000  December        16.0          124.0   1901.47           11.0
# 1     1001    August        27.0          182.0   6919.15           30.0
# 2     1001  December        56.0          412.0  19369.18           44.0
# 3     1001  November        64.0          426.0  18504.30           36.0
# 4     1001   October        65.0          393.0  22330.49           53.0
#
#        plan
# 0  ultimate
# 1      surf
# 2      surf
# 3      surf
# 4      surf

# %%
df_usage['Minutes Spent'] = df_usage['Minutes Spent'].apply(np.ceil)
df_usage['Mb Used']       = df_usage['Mb Used'].apply(np.ceil)
df_usage.head()
# Out:
#    user_id     month  Calls Made  Minutes Spent  Mb Used  Messages Sent  \
# 0     1000  December        16.0          124.0   1902.0           11.0
# 1     1001    August        27.0          182.0   6920.0           30.0
# 2     1001  December        56.0          412.0  19370.0           44.0
# 3     1001  November        64.0          426.0  18505.0           36.0
# 4     1001   October        65.0          393.0  22331.0           53.0
#
#        plan
# 0  ultimate
# 1      surf
# 2      surf
# 3      surf
# 4      surf

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# I would suggest some issues here: could you please check Megaline's rules about rounding up of calls (as mentioned above) as well as gigabytes? For web traffic, individual web sessions are not rounded up. Instead, the total for the month is rounded up. If someone uses 1025 megabytes this month, they will be charged for 2 gigabytes.
# </div>

# %% [markdown]
# * [X] rounding of calls and internet traffic was done.

# %%
df_usage['over_minutes'], df_usage['over_traffic'], df_usage['over_messages'] = calculate_overage(df_usage, df_plans)
df_usage.head()
# Out:
#    user_id     month  Calls Made  Minutes Spent  Mb Used  Messages Sent  \
# 0     1000  December        16.0          124.0   1902.0           11.0
# 1     1001    August        27.0          182.0   6920.0           30.0
# 2     1001  December        56.0          412.0  19370.0           44.0
# 3     1001  November        64.0          426.0  18505.0           36.0
# 4     1001   October        65.0          393.0  22331.0           53.0
#
#        plan  over_minutes  over_traffic  over_messages
# 0  ultimate           0.0           0.0            0.0
# 1      surf           0.0           0.0            0.0
# 2      surf           0.0        4010.0            0.0
# 3      surf           0.0        3145.0            0.0
# 4      surf           0.0        6971.0            3.0

# %%
df_usage.isnull().sum()
# Out:
# user_id          0
# month            0
# Calls Made       0
# Minutes Spent    0
# Mb Used          0
# Messages Sent    0
# plan             0
# over_minutes     0
# over_traffic     0
# over_messages    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Good work! Let's calculate the revenue.
# </div>

# %% [markdown]
# #### Calculation Revenue <a name="CalculationRevenue"></a>

# %%
# let's see again usage table with new added columns:
df_usage.head()
# Out:
#    user_id     month  Calls Made  Minutes Spent  Mb Used  Messages Sent  \
# 0     1000  December        16.0          124.0   1902.0           11.0
# 1     1001    August        27.0          182.0   6920.0           30.0
# 2     1001  December        56.0          412.0  19370.0           44.0
# 3     1001  November        64.0          426.0  18505.0           36.0
# 4     1001   October        65.0          393.0  22331.0           53.0
#
#        plan  over_minutes  over_traffic  over_messages
# 0  ultimate           0.0           0.0            0.0
# 1      surf           0.0           0.0            0.0
# 2      surf           0.0        4010.0            0.0
# 3      surf           0.0        3145.0            0.0
# 4      surf           0.0        6971.0            3.0

# %%
# function to calculate revenue for each user.
def calculation_revenue(df, df_plan):
    
    revenue  = []
    user_sum = 0

    #surf costs:
    surf_month_cost  = 20
    surf_minute_cost  = 0.03
    surf_message_cost = 0.03
    surf_1Gb_cost     = 10
    
    #ultimate costs:
    ultimate_month_cost   = 70
    ultimate_minute_cost  = 0.01
    ultimate_message_cost = 0.01
    ultimate_1Gb_cost     = 7
    
    for over_minutes, over_traffic, over_messages, plan in zip(df['over_minutes'], df['over_traffic'], df['over_messages'], df['plan']):
        if plan == 'ultimate':
            user_sum += ultimate_month_cost
            user_sum += ultimate_message_cost * over_messages
            user_sum += ultimate_1Gb_cost * (over_traffic / 1024) # we will calculate traffic in Gbytes
            user_sum += ultimate_minute_cost * over_minutes
        else:
            user_sum += surf_month_cost
            user_sum += surf_message_cost * over_messages
            user_sum += surf_1Gb_cost * (over_traffic / 1024) # we will calculate traffic in Gbytes
            user_sum += surf_minute_cost * over_minutes
        revenue.append(user_sum)
        user_sum = 0
    return revenue

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Could you please check if we use the rounded up to gigabit internet traffic?
# </div>

# %% [markdown]
# * [X] rounding of calls and internet traffic was done.

# %%
df_usage['revenue'] = calculation_revenue(df_usage, df_plans)
display(df_usage.head(20))
print('Mean revenue value:', df_usage['revenue'].mean())
# Out:
#     user_id      month  Calls Made  Minutes Spent  Mb Used  Messages Sent  \
# 0      1000   December        16.0          124.0   1902.0           11.0
# 1      1001     August        27.0          182.0   6920.0           30.0
# 2      1001   December        56.0          412.0  19370.0           44.0
# 3      1001   November        64.0          426.0  18505.0           36.0
# 4      1001    October        65.0          393.0  22331.0           53.0
# 5      1001  September        49.0          315.0  13315.0           44.0
# 6      1002   December        47.0          384.0  14397.0           41.0
# 7      1002   November        55.0          386.0  19346.0           32.0
# 8      1002    October        11.0           59.0   6553.0           15.0
# 9      1003   December       149.0         1104.0  27045.0           50.0
# 10     1004     August        49.0          354.0  27982.0           25.0
# 11     1004   December        50.0          427.0  21390.0           31.0
# ...

# %% [markdown]
# #### Step 2: Conclusion <a name="Step2Conclusion"></a>

# %% [markdown]
# > * At this step, the main task was to use the current data and transform it to create new useful columns with information in order to subsequently analyze it and draw conclusions.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# Well done! We prepared the data for the analysis.
# </div>

# %% [markdown]
# ### Step 3. Analyze the data <a name="AnalyzeData"></a>

# %% [markdown]
# > - Describe the customers' behavior. Find the minutes, texts, and volume of data the users of each plan require per month. Calculate the mean, variance, and standard deviation. Plot histograms. Describe the distributions.

# %%
# we will prepare separate ones for two tariff plans.
df_usage_surf     = df_usage.query('plan == "surf"')[['user_id', 'month', 'Minutes Spent', 'Mb Used', 'Messages Sent', 'revenue']]
df_usage_ultimate = df_usage.query('plan == "ultimate"')[['user_id', 'month', 'Minutes Spent', 'Mb Used', 'Messages Sent', 'revenue']]

# %%
df_usage_surf.to_csv('df_usage_surf.csv', index=False)
df_usage_ultimate.to_csv('df_usage_ultimate.csv', index=False)

# %% [markdown]
# Let's add the key factors, from my point of view, of the tariff plans:

# %% [markdown]
# **Surf:**
# > - Monthly charge: 20 dollars
# - **500** monthly minutes, **50** texts, and **15** GB of data
# - 1 GB of data: $10

# %%
# sort for first view Surf plan:
display(df_usage_surf.sort_values(by='revenue', ascending=False).head())
# check main parameter for Surf plan:
df_usage_surf.describe()
# Out:
#       user_id     month  Minutes Spent  Mb Used  Messages Sent     revenue
# 1755     1379  December         1103.0  70932.0          126.0  583.065313
# 569      1121  December            0.0  66864.0           97.0  524.378750
# 1357     1292  December          144.0  52035.0            0.0  378.154297
# 1356     1292    August          323.0  51810.0            0.0  375.957031
# 1126     1240    August         1095.0  49951.0           15.0  375.652734
#            user_id  Minutes Spent       Mb Used  Messages Sent      revenue
# count  1573.000000    1573.000000   1573.000000    1573.000000  1573.000000
# mean   1242.755245     428.749523  16558.776860      31.159568    57.675606
# std     139.227939     234.453150   8013.516423      33.566717    53.861753
# min    1001.000000       0.000000      0.000000       0.000000    20.000000
# 25%    1120.000000     272.000000  11987.000000       3.000000    20.000000
# ...

# %% [markdown]
# Let's look at another random special case, a user with an id=1499 which used Surf plan:

# %%
df_usage_surf.query('user_id == "1499"').describe()
# Out:
#        user_id  Minutes Spent       Mb Used  Messages Sent    revenue
# count      4.0       4.000000      4.000000            4.0   4.000000
# mean    1499.0     383.750000  17838.000000            0.0  49.997559
# std        0.0      81.168036   3880.055584            0.0  28.938351
# min     1499.0     308.000000  12985.000000            0.0  20.000000
# 25%     1499.0     336.500000  15856.750000            0.0  30.649414
# 50%     1499.0     365.500000  18153.500000            0.0  47.280273
# 75%     1499.0     412.750000  20134.750000            0.0  66.628418
# max     1499.0     496.000000  22060.000000            0.0  85.429688

# %% [markdown]
# **Ultimate:**
# > - Monthly charge: 70 dollars
# - **3000** monthly minutes, **1000** text messages, and **30** GB of data
# - 1 GB of data: $7

# %%
display(df_usage_ultimate.sort_values(by='revenue', ascending=False).head())
df_usage_ultimate.describe()
# Out:
#       user_id     month  Minutes Spent  Mb Used  Messages Sent     revenue
# 103      1028   October           39.0  46596.0           73.0  178.527344
# 2239     1490  December          368.0  46216.0            0.0  175.929688
# 135      1038  December          475.0  45021.0          113.0  167.760742
# 102      1028  November           69.0  42953.0           77.0  153.624023
# 95       1028    August           76.0  40389.0           74.0  136.096680
#            user_id  Minutes Spent       Mb Used  Messages Sent     revenue
# count   720.000000     720.000000    720.000000     720.000000  720.000000
# mean   1253.330556     430.450000  17215.202778      37.551389   72.116292
# std     150.915644     240.508762   7851.886627      34.767179   10.769582
# min    1000.000000       0.000000      0.000000       0.000000   70.000000
# 25%    1126.000000     260.000000  12667.500000       7.000000   70.000000
# ...

# %%
# function for created histograms - first draft.
def plot_histograms(df1,df2,column,bins_1,bins_2):
    ax = df1.hist(column=column, density=True, bins=bins_1, figsize=(16,5))
    df2.hist(column=column, density=True, bins=bins_2, alpha=0.4, ax=ax)
    plt.legend(['surf_plan', 'ultimate_plan'])
    plt.xlabel(column)
    plt.show()

# %%
# another type of function for create 1 types of histograms in one chart:
def plot_histograms_1(df1, df2, column, bins_1, bins_2):
    fig, ax = plt.subplots(figsize=(16,5))
    df1.hist(column=column, ax=ax, density=True, bins = bins_1)
    df2.hist(column=column, ax=ax, density=True, bins = bins_2)
    #plt.xticks(ticks,ticks)
    plt.title(column)
    plt.xlabel(column)
    plt.legend(['Surf,' + ' ' +column, 'Ultimate,' + ' ' +column])
    plt.show()

# %%
# another type of function for create 2 types of histograms in one chart:
def plot_histograms_2(df1, df2, column, bins_1, bins_2, lim_1, lim_2):
    fig, ax = plt.subplots(figsize=(16,5))
    df1.hist(column=column, ax=ax, density=True, bins = bins_1, range   = (lim_1, lim_2))
    df2.hist(column=column, ax=ax, density=True, bins = bins_2, range   = (lim_1, lim_2))
    plt.title(column)
    plt.xlabel(column)
    plt.legend(['Surf,' + ' ' +column, 'Ultimate,' + ' ' +column])
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment v.1</b>
#
# It is good that you like functions! You mastered it!
# </div>

# %%
plot_histograms_1(df_usage_surf, df_usage_ultimate, 'Minutes Spent', 50, 100)

# %% [markdown]
# > * **Chart Description:** The main number of minutes spent on both tariff plans is the same and ranges from 200 to 600 minutes.

# %%
plot_histograms_1(df_usage_surf, df_usage_ultimate, 'Mb Used', 50, 100)

# %% [markdown]
# > * **Chart Description:** Users of both tariffs usually use the same amount of traffic. From 1 to 2 gigabytes.

# %%
plot_histograms_2(df_usage_surf, df_usage_ultimate, 'Messages Sent', 50, 100, 0, 200)

# %% [markdown]
# > * **Description:** The number of messages sent is between 0 and 50 messages. From 50 to 100, the number of sent messages is higher on the Ultimate plan.

# %%
plot_histograms_1(df_usage_surf, df_usage_ultimate, 'revenue', 20, 20)

# %%
plot_histograms_2(df_usage_surf, df_usage_ultimate, 'revenue', 20, 20, 20, 250)

# %% [markdown]
# > * **Description:**
# * The main income distribution on the Ultimate tariff plan is fixed at 70 dollars per month. This is the monthly cost of this tariff plan. But there are also separate groups of users who spend more on this tariff plan. The maximum income is 178.5 dollars per month.
# * The main income distribution on the Surf tariff plan is fixed at 20 dollars per month. This is the monthly cost of this tariff plan. But there are also separate groups of users who spend more on this tariff plan. The maximum income outliers on level 581.4 dollars per month.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Correct! You have made conclusions for each histogram. However, I would suggest that this part of the data analysis could be improved. According to the Project description, at this stage, we should "Describe the customers' behavior. Find the minutes, texts, and volume of data the users of each plan require per month. Calculate the mean, dispersion, and standard deviation. Plot histograms. Describe the distributions".
#
# Could you please add:
# - summarise conclusion that edscribe the customers' behavior for each plan;
# - the mean, variance, and standard deviation for minutes, texts, and volume of data the users of each plan require per month (now the project has just mean and standard deviation)
# - the description of the distributions.
#
# You plotted good graphs. However, please check that graphs have the y-axis labels.
#
# </div>

# %% [markdown]
# * [X] Done. Updated Conclusion 3.
# [* Step 3: Conclusion](#Step3Conclusion)

# %%
# add new hierarchy with all months:
month_hierarchy = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August','September','October','November', 'December']
# let's add new column with months:
df_usage['month'] = pd.Categorical(df_usage['month'], month_hierarchy)
df_usage.dtypes
# Out:
# user_id             int64
# month            category
# Calls Made        float64
# Minutes Spent     float64
# Mb Used           float64
# Messages Sent     float64
# plan               object
# over_minutes      float64
# over_traffic      float64
# over_messages     float64
# revenue           float64
# dtype: object

# %%
group_month_revenue = df_usage.groupby(['plan','month']).agg({'Minutes Spent':'sum', 'Mb Used':'sum','Messages Sent':'sum', 'revenue':'sum'})
display(group_month_revenue)
# Out:
#                     Minutes Spent     Mb Used  Messages Sent       revenue
# plan     month
# surf     January           385.68     9749.72           21.0     40.000000
#          February         2527.66   109609.59          108.0    297.090000
#          March            7152.31   306945.12          351.0   1002.419453
#          April           16619.00   599210.15          870.0   1939.150703
#          May             29033.10  1073099.33         1849.0   3492.206797
#          June            39499.26  1484248.33         2454.0   4454.952188
#          July            51367.31  2030815.67         3271.0   7160.620937
#          August          62721.48  2720843.68         4662.0   9826.451484
#          September       75852.46  3218737.67         5968.0  10656.431641
#          October         96149.09  4102786.41         8020.0  14611.924453
#          November       113086.75  4624009.00         9165.0  15547.878125
# ...

# %%
# write new function for create plot:
def plot_dataframe(group_df, group, column, title):
    plt.figure(figsize=(16,5))
    group_df.xs(group[0])[column].plot()
    group_df.xs(group[1])[column].plot()
    plt.title(title)
    plt.legend(['Surf,' + ' ' +column, 'Ultimate,' + ' ' +column])
    plt.show()

# %%
plot_dataframe(group_month_revenue,['surf','ultimate'], 'Minutes Spent', 'Minutes Spent per Month')
plot_dataframe(group_month_revenue,['surf','ultimate'], 'Mb Used', 'Mb Used per Month')
plot_dataframe(group_month_revenue,['surf','ultimate'], 'Messages Sent', 'Messages Sent per Month')
plot_dataframe(group_month_revenue,['surf','ultimate'], 'revenue', 'Revenue per Month')

# %% [markdown]
# Description of charts:
# > * The number of minutes spent, the volume of traffic, sent messages and revenue from the tariff coincide at the very beginning of the month for both tariff plans - Surf and Ultimate.
# * But by the end of the month, the same indicators for different tariff plans change. On the Surf plan, the amount of user costs increases in total. Thus, the company's revenue from this tariff plan increases.

# %% [markdown]
# #### Step 3: Conclusion:<a name="Step3Conclusion"></a>

# %% [markdown]
# * According to the description of the tariff plan Surf, it contains - 500 minutes of calls, 50 text messages and 15 gigabytes of traffic. In the dataset, it is shown that the average value of minutes spent is 428, messages sent is 31, and megabytes used is 16558 megabytes. Thus, we can conclude that users on this tariff plan do not fit only into the traffic volume. There is an overrun on this point. We can say that this tariff most often earns on the used megabytes.
# * In 50% of cases, this tariff plan earns 37 dollars and more. And the average amount paid by users when the limits are exceeded is 57 dollars. This is despite the fact that the cost of a monthly subscription fee is 20 dollars. Thus, this tariff plan provides additional extra profit 3 times higher than the cost of the subscription fee. It is this 3-fold excess that we see on the Internet traffic.
# * One example is my favorite user wiht user_id=1499, a 37-year-old woman by name - Shena	Dickson, who spends on the Surf plan, who loves to use the Internet and pays a maximum of 85 dollars per month in excess of the plan.
# * The situation is different on the Yultimate tariff plan. Here, for 70 dollars, none of the three resources of the tariff is used to the full, and even more so does not exceed the permissible limits. Only individual users spend practically the average traffic of the Surf tariff plan - about 16 gigabytes. And that's at 7 dollars per gigabyte.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Good conclusions and graphs! I guess in this case, we could also count the number of users. Also, we could plot the same graphs with mean values for each type of communication per month.
# </div>

# %% [markdown]
# ### Step 4. Test the Hypotheses <a name="Step4Hypotheses"></a>

# %% [markdown]
# > - [x] The average revenue from users of Ultimate and Surf calling plans differs.
# - [X] The average revenue from users in NY-NJ area is different from that of the users from other regions.

# %% [markdown]
# **Explain:**

# %% [markdown]
# > - [X] How you formulated the null and alternative hypotheses.
# - [X] What criterion you used to test the hypotheses and why.

# %% [markdown]
# #### Null Hypotheses 1: <a name="NullHypotheses1"></a>

# %% [markdown]
# * The first Null Hypotheses 1:

# %% [markdown]
# > Average revenue from users of Ultimate and Surf calling plans NOT DIFFERENT.

# %% [markdown]
# * Alternative Hypotheses 1:

# %% [markdown]
# > Average revenue from users of Ultimate and Surf calling plans DIFFERENT.

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Good! The both null and alternative hypotheses have been defined!</div>

# %%
# first need to prepare patterns: for SURF and ULTIMATE plans:
sample_surf     = df_usage.groupby(['plan'])['revenue'].get_group('surf')
sample_ultimate = df_usage.groupby(['plan'])['revenue'].get_group('ultimate')

print('Mean value for Surf Plan:', sample_surf.mean())
print('Mean value for Ultimate Plan:', sample_ultimate.mean())
# Out:
# Mean value for Surf Plan: 57.30113085068341
# Mean value for Ultimate Plan: 72.11629231770833

# %%
# define function for check hypotheses:
def test_hypotheses(pattern_1, pattern_2):
    alpha   = .05
    results = st.ttest_ind(pattern_1, pattern_2)

    print('pvalue:', results.pvalue)
    print('alpha:', alpha)
    if results.pvalue < alpha:
        print('Decision: We reject the null hypotheses')
    else:
        print('Decision: We cannot reject the null hypotheses')

# %%
# for check hypotheses upload patterns for Surf and Ultimate plans:
test_hypotheses(sample_surf, sample_ultimate)
# Out:
# pvalue: 3.1830477744750944e-13
# alpha: 0.05
# Decision: We reject the null hypotheses

# %% [markdown]
# #### Null Hypotheses 1 Conclusion: <a name="NullHypotheses1Conclusion"></a>

# %% [markdown]
# > * Based on the fact that the Null hypothesis was **REJECTED**, it can be **CONFERMED** that the alternative hypothesis that "the average revenue from users of Ultimate and Surf calling plans is **DIFFERENT**"

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Correct!
# </div>

# %% [markdown]
# #### Null Hypotheses 2: <a name="NullHypotheses2"></a>

# %% [markdown]
# * The first Null Hypotheses 2:

# %% [markdown]
# > The average revenue from users in NY-NJ area is NOT DIFFERENT from that of the users from other regions.

# %% [markdown]
# * Alternative Hypotheses 2:

# %% [markdown]
# > The average revenue from users in NY-NJ area is DIFFERENT from that of the users from other regions.

# %%
# first need to prepare patterns for NY-NJ area and other regions.
# add condition expression for NY-NJ area.
NY_NJ_users_bool = df_users['city'].apply(lambda x: True if 'NY-NJ' in x else False)
NY_NJ_users      = df_users[NY_NJ_users_bool]['user_id'].values.tolist()

# create new df for NY-NJ area and other regions.
sample_NY_NJ     = df_usage[df_usage['user_id'].isin(NY_NJ_users)]['revenue']
sample_other     = df_usage[~df_usage['user_id'].isin(NY_NJ_users)]['revenue']

print('Mean value for NY-NJ area:', sample_NY_NJ.mean())
print('Mean value for other regions:', sample_other.mean())
# Out:
# Mean value for NY-NJ area: 57.19647971236738
# Mean value for other regions: 62.88900649546582

# %%
test_hypotheses(sample_NY_NJ, sample_other)
# Out:
# pvalue: 0.026135219715942206
# alpha: 0.05
# Decision: We reject the null hypotheses

# %% [markdown]
# #### Null Hypotheses 2 Conclusion: <a name="NullHypotheses2Conclusion"></a>

# %% [markdown]
# > * Based on the fact that the Null hypothesis was **REJECTED**, it can be **CONFERMED** that the alternative hypothesis that "the average revenue from users in NY-NJ area is **DIFFERENT** from that of the users from other regions"

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <b>Reviewer's comment v.1</b>
#
# Correct!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v.1</b>
#
# I would note, that in this case we also could use the Student's t-test. In fact, the t-test can be robust to the non-normally distributed data in cases when we have more than 30-50 entries in the datasets. It is based on the Central limit theorem:
# - https://sphweb.bumc.bu.edu/otlt/mph-modules/bs/bs704_probability/BS704_Probability12.html
#
# Before testing statistical hypotheses using the Student's t-test, it is important to understand whether our data adhere to the assumptions that this statistical test makes for our compared samples. One of these assumptions is the homogeneity (equality) of variances. An obligatory action before testing statistical hypotheses is to check the homogeneity of the variances of the two compared samples. This is necessary in order to understand with which parameter to use the test method (`Student's t-test` or `Welch's t-test`) and specify the `equal_var` argument inside the `st.ttest_ind` method (you can read more in the scipy documentation: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html)
#     <br/>
#
# To check whether the assumption of dispersion homogeneity is met you can use the [Levene's test] (https://medium.com/@kyawsawhtoon/levenes-test-the-assessment-for-equality-of-variances-94503b695a57), which is implemented in the scipy library. The method allows you to estimate the equality of variances using the p-level of significance. You can also read more about this method in the documentation:
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html
#
# The only caveat: `Levene's test` suggests that the samples are not normally distributed:
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html
#
# How to check the normal distribution of samples? The `Shapiro-Wilk` test can be used:
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html
#
# It allows you to check samples for normality. AND:
# - If, according to the results of conducting the test, we see that normality is observed, we use the [Bartlett] test to check the equality (homogeneity) of variances (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.bartlett.html) (check for equality of variances of two normally distributed samples)
# - Otherwise, Levene's test.
#
# And then we already set the value of the `equal_var` ttest_ind parameter. Also, the t-test does not like outliers.
#
# <br>
# P.S. See the material by the links
# - https://thestatsgeek.com/2013/09/28/the-t-test-and-robustness-to-non-normality/
# - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6676026/
# </div>

# %% [markdown]
# ### Step 5. Write an overall conclusion <a name="OverallConclusion"></a>

# %% [markdown]
# > * The graphs built in the 3rd step show that the Surf tariff plan brings more revenue to the company than the Ultimate tariff plan.
# * Also, hypothesis testing shows that tariff plans give different incomes.

# %% [markdown]
# > * The main proposal on my part is the expansion of the tariff scale, the creation of new tariffs. Two tariff plans are “dangerously low” for a telecommunications company. In this case, my proposal is the introduction of new tariff plans with different settings for the limits in them.
# * And here there are 2 ways - this is investing in tariff plans like Surf. At the same time, changing the limits of these tariff plans. For example, you can enter the RasPutin21 tariff plan. The price will be 14.99 dollars per month. It will include 20 + 1 (free) Gigabytes of Internet traffic, 400 minutes and 40 SMS. At the same time, the price in excess of the excess for 1 minute is 7 cents, for 1 message - 7 cents, for 1 Gigabyte of data - 30 dollars. I would say that this tariff will be based on one of the human vices - greed. A person wanting to save money will think that he will meet the current limits by paying even less. At the same time, as statistics show, the bulk of users will exceed the limits.
# * Another way is investing money in a tariff plan based on Ultimate. Here you can not change the limits too much, since most users do not exceed them. But at the same time, think about additional functionality that can be offered to the user. For example, a tariff plan with a higher data transfer rate, while at the same time with a higher subscriber cost.
#
# P.S. Non-official. Dear friends, from the commercial department. It seems that your company is called Rostelecom or Tattelecom, in the distant country of Russia. Or you are the commercial department of Rosneft or Gazprom. The feeling that you are still living in zero years or you have an oil pipe, the profit from which will really end soon. It seems to me that something needs to be done about this. :)))

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment v.1</b>
#
# I would suggest that there is a minor issue: you have made a lot of correct steps! Your code sometimes looks professional. By the way, to be an analyst, we have to make data-based conclusions. Some of them - is a description of data and our findings, others - about technical problems with data, but the most important ones - insights useful for business. It is complicated and interesting.
#
# Could you please suggest some suggestings for Megaline?
# </div>

# %% [markdown]
# * [X] Update overall conclusion - Done.

# %% [markdown]
# Quetion for reviewer: what resourses better to read how write conclusion.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment v.1</b>
#
# Kamil, thank you for your question. It is not easy to answer. I think that there is no single answer. Conclusions depend on the type of analysis and on the client and what the client wants to have.
#
# In general, overall conclusions should answer the main question(s) of the project. In our case, the main questions (according to project description): `analyze clients' behavior` and `determine which prepaid plan is more profitable`. So, in this project, overall conclusions should contain:
# 1. profiles of the average client for both plans (and their comparing as an additional conclusion);
# 2. suggesting about which prepaid plan is more profitable.
#
# The conclusions should be based on the main results of the project and contain them in brief form. I prefer when overall conclusions also contain:
# - a brief review of the work with a description of the main project steps and their intermediate conclusions;
# - some recommendations for business;
# - if it's necessary - description of the technical problems with data.
#
# Let's try to make conclusions here! If it is hard - I will help you in the next iteration of the review.
# </div>

# %% [markdown]
# P.s. I wonder what articles you read. If you are on linkedin, you can add me: https://www.linkedin.com/in/kamil-kanafin-a21a8a7a/. I'm trying to find out more about which of the professional analysts is reading what, and so on. Well, I am expanding the circle of professional communication.
